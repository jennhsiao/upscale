# %%
import xarray as xr
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob
import cartopy
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import cartopy.io.shapereader as shpreader
import os

# %%
siteyears = pd.read_csv('/home/disk/eos8/ach315/upscale/weadata/site_years.csv', index_col=0)
siteyears.head()
# Out:
#    site  years
# 0  3103     21
# 1  3812     20
# 2  3813     21
# 3  3820     19
# 4  3822     20

# %%
siteyears[siteyears.years >= 15].shape
# Out:
# (176, 3)

# %%
siteyears[siteyears.years >= 20].shape
# Out:
# (112, 3)

# %%
siteyears[siteyears.years >= 25].shape
# Out:
# (6, 3)

# %%
# location info for yield data
state = pd.read_csv('/home/disk/eos8/ach315/data/NASS_cropdata/stateID.txt', header=None, sep='\s+')
county = pd.read_csv('/home/disk/eos8/ach315/data/NASS_cropdata/countyID.txt', header=None, sep='\s+')
lat = pd.read_csv('/home/disk/eos8/ach315/data/NASS_cropdata/lat_county.txt', header=None, sep='\s+')
lon = pd.read_csv('/home/disk/eos8/ach315/data/NASS_cropdata/lon_county.txt', header=None, sep='\s+')

state = state.iloc[0,:]
county = county.iloc[0,:]
lat = lat.iloc[0,:]
lon = lon.iloc[0,:]

df_loc = pd.DataFrame({'state': state, 'county': county, 'lat': lat, 'lon': lon})

# %%
# yield & planting area data
df_yield = pd.read_csv('/home/disk/eos8/ach315/data/NASS_cropdata/corn_yield.txt', header=None, sep='\s+')
df_area = pd.read_csv('/home/disk/eos8/ach315/data/NASS_cropdata/corn_area.txt', header=None, sep='\s+')

# %%
# irrigation data
state = pd.read_csv('/home/disk/eos3/aswann/Shared/Data/irrigated_area/stateID.txt', header=None, sep='\s+')
county = pd.read_csv('/home/disk/eos3/aswann/Shared/Data/irrigated_area/countyID.txt', header=None, sep='\s+')
lat = pd.read_csv('/home/disk/eos3/aswann/Shared/Data/irrigated_area/lat_county.txt', header=None, sep='\s+')
lon = pd.read_csv('/home/disk/eos3/aswann/Shared/Data/irrigated_area/lon_county.txt', header=None, sep='\s+')
irri = pd.read_csv('/home/disk/eos3/aswann/Shared/Data/irrigated_area/irr_area_acres.txt', header=None, sep='\s+')
area = pd.read_csv('/home/disk/eos3/aswann/Shared/Data/irrigated_area/crop_area_acres.txt', header=None, sep='\s+')
state = state.iloc[0,:]
county = county.iloc[0,:]
lat = lat.iloc[0,:]
lon = lon.iloc[0,:]
irri = irri.iloc[:,3]
area = area.iloc[:,3]

df_irri = pd.DataFrame({'state': state, 'county': county, 'lat': lat, 'lon': lon, 
                        'irri_area': irri, 'crop_area': area, 'perct_irri': irri/area*100})

# %%
df_irri.head()
# Out:
#    state  county        lat        lon  irri_area  crop_area  perct_irri
# 0    1.0     1.0  32.430976 -86.714727     1555.0    41293.0    3.765771
# 1    1.0     3.0  30.569698 -87.688916     7678.0   100901.0    7.609439
# 2    1.0     5.0  31.907512 -85.306271     2301.0    41301.0    5.571294
# 3    1.0     7.0  33.069184 -87.075724       55.0    12608.0    0.436231
# 4    1.0     9.0  34.021667 -86.653387      516.0    37147.0    1.389076

# %%
from palettable.colorbrewer.sequential import YlGnBu_8

fig = plt.figure(figsize=(8,5))
extent = [-123, -72, 19, 53]
ax = plt.axes(projection=ccrs.AlbersEqualArea(central_latitude=39.5, central_longitude=-98.35))
ax.scatter(df_irri.lon, df_irri.lat, transform=ccrs.PlateCarree(),            
           c=df_irri.perct_irri*0.1, s=50, vmin=0, vmax=10, alpha=0.5, cmap=YlGnBu_8.mpl_colormap)
ax.set_extent(extent)
ax.add_feature(cfeature.COASTLINE, edgecolor='grey')
ax.add_feature(cfeature.BORDERS, edgecolor='grey')
ax.add_feature(cfeature.STATES, edgecolor='grey', linewidth=0.5)
ax.set_title('percent irrigated (year 2012)', 
              fontweight='light', fontsize=18)
# Out:
# Text(0.5, 1.0, 'percent irrigated (year 2012)')

# %%
pd.concat([df_loc_maize, df_loc_irri]).drop_duplicates(keep=False)
# Out:
#       state  county
# 2885   51.0   560.0
# 222     8.0    14.0
# 560    17.0     0.0
# 663    18.0     0.0
# 1144   23.0     0.0
# 1199   26.0     0.0
# 1283   27.0     0.0
# 1798   36.0     0.0
# 2014   39.0     0.0
# 2216   42.0     0.0
# 2927   53.0     0.0
# 3022   55.0     0.0

# %%
from palettable.colorbrewer.sequential import YlGn_9

fig = plt.figure(figsize=(8,5))
extent = [-123, -72, 19, 53]
ax = plt.axes(projection=ccrs.AlbersEqualArea(central_latitude=39.5, central_longitude=-98.35))
ax.scatter(ds_yield.lon, ds_yield.lat, transform=ccrs.PlateCarree(), s=ds_yield.sel(time=1990)['area']*0.005,
           c=ds_yield.sel(time=1990)['yield'], vmin=0, vmax=10, alpha=0.5,
           cmap=YlGn_9.mpl_colormap)
ax.set_extent(extent)
ax.add_feature(cfeature.COASTLINE, edgecolor='grey')
ax.add_feature(cfeature.BORDERS, edgecolor='grey')
ax.add_feature(cfeature.STATES, edgecolor='grey', linewidth=0.5)
ax.set_title('US maize yield (1990)', 
              fontweight='light', fontsize=18)

# %%
ds_yield = xr.Dataset({'yield': (['county', 'time'], maize_yield),
                       'area': (['county', 'time'], maize_area)},
                      coords = {'county': np.arange(1,3109),
                                'time': np.arange(1910,2015),
                                'lat': lat,
                                'lon': lon},
                      attrs = {'yield': 'specify units',
                               'area': 'specify units'})

# %%
ds_yield
# Out:
# <xarray.Dataset>
# Dimensions:  (county: 3108, lat: 3108, lon: 3108, time: 105)
# Coordinates:
#   * county   (county) int64 1 2 3 4 5 6 7 ... 3102 3103 3104 3105 3106 3107 3108
#   * time     (time) int64 1910 1911 1912 1913 1914 ... 2010 2011 2012 2013 2014
#   * lat      (lat) float64 32.46 30.79 31.87 33.07 ... 44.2 41.28 43.9 43.8
#   * lon      (lon) float64 -86.71 -87.71 -85.38 -87.11 ... -110.5 -107.8 -104.6
# Data variables:
#     yield    (county, time) float64 nan nan nan nan nan ... nan nan nan nan nan
#     area     (county, time) float64 nan nan nan nan nan ... nan nan nan nan nan
# Attributes:
#     yield:    specify units
#     area:     specify units

# %%
from palettable.colorbrewer.sequential import YlGn_9

fig = plt.figure(figsize=(8,5))
extent = [-123, -72, 19, 53]
ax = plt.axes(projection=ccrs.AlbersEqualArea(central_latitude=39.5, central_longitude=-98.35))
ax.scatter(ds_yield.lon, ds_yield.lat, transform=ccrs.PlateCarree(), s=ds_yield.sel(time=1990)['area']*0.005,
           c=ds_yield.sel(time=1990)['yield'], vmin=0, vmax=10, alpha=0.5,
           cmap=YlGn_9.mpl_colormap)
ax.set_extent(extent)
ax.add_feature(cfeature.COASTLINE, edgecolor='grey')
ax.add_feature(cfeature.BORDERS, edgecolor='grey')
ax.add_feature(cfeature.STATES, edgecolor='grey', linewidth=0.5)
ax.set_title('US maize yield (1990)', 
              fontweight='light', fontsize=18)
# Out:
# Text(0.5, 1.0, 'US maize yield (1990)')

# %%
path = '/home/disk/eos8/ach315/upscale/sims/opt/1961/var_0/out1_03813_1961_var_0.txt'
with open(path) as file:
    content = file.read()

# %%
test = [line.split(',') for line in content.split('\n')]

# %%
test[2]
# Out:
# ['04/01/1961',
#  ' 22372',
#  '       1',
#  '    0.00',
#  '       0',
#  '       0',
#  '     0.00',
#  '     0.00',
#  '    0.00',
#  '   80.33',
#  ' -0.0500',
#  '    0.00',
#  '    0.00',
#  '   15.45',
#  '   14.40',
#  '   15.45',
#  '     0.000',
#  '     0.000',
#  '  0.0000',
#  '  0.0000',
#  '  0.0000',
#  '  0.0000',
#  '       0.000',
#  '       0.000',
#  '        0.00',
#  '        0.00',
#  '      0.0000',
#  '      0.0000',
#  '      0.0000',
#  '      0.0000',
#  '      0.0000',
#  '      0.0000',
#  '    0.000',
#  '    0.0094',
#  '    0.0000',
#  '    0.0000',
#  '    0.0074',
#  '    0.0000',
#  '   0.275',
#  '   0.165',
#  '    0.00',
#  '    0.15',
#  '    0.00',
#  '    0.02',
#  '   0.110',
#  '   0.000',
#  '     0.0',
#  '       0.000',
#  '    0.00',
#  '              "none"']
