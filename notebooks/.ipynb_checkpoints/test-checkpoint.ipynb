# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
test = pd.read_csv('/home/disk/eos8/ach315/maizsim_200102/MAIZSIM/testruns/out1.g01', index_col=False)
test.head()
# Out:
#          date      jday   time     Leaves   MaturLvs    Dropped  LA/pl  \
# 0  05/12/2006     38849      0        0.0          0          0    0.0
# 1  05/12/2006     38849      1        0.0          0          0    0.0
# 2  05/12/2006     38849      2        0.0          0          0    0.0
# 3  05/12/2006     38849      3        0.0          0          0    0.0
# 4  05/12/2006     38849      4        0.0          0          0    0.0
#
#       LA_dead   LAI      RH  ...  earDM    TotleafDM  DrpLfDM    stemDM  \
# 0         0.0   0.0   66.27  ...  0.165          0.0     0.15       0.0
# 1         0.0   0.0   68.51  ...  0.165          0.0     0.15       0.0
# 2         0.0   0.0   77.52  ...  0.165          0.0     0.15       0.0
# 3         0.0   0.0   82.41  ...  0.165          0.0     0.15       0.0
# 4         0.0   0.0   95.70  ...  0.165          0.0     0.15       0.0
#
#     rootDM   SoilRt   MxRtDep  AvailW   solubleC  Note
# ...

# %%
test.columns
# Out:
# Index(['date', '    jday', ' time', '   Leaves', ' MaturLvs', '  Dropped',
#        'LA/pl', '   LA_dead', ' LAI', '    RH', '     LeafWP', ' PFD',
#        '    SolRad', ' SoilT', '  Tair', '   Tcan', '   ETdmd', '     ETsply',
#        '    Pn', '  Pg', '     Respir', '   av_gs', '  sunlit_LAI',
#        ' shaded_LAI', ' sunlit_PFD', ' shaded_PFD', ' sunlit_An',
#        '  shaded_An', '  sunlit_Ag', '  shaded_Ag', '  sunlit_gs',
#        '  shaded_gs   VPD', '     Nitr', '     N_Dem', '    NUpt',
#        '     LeafN', '    PCRL', '     totalDM', 'shootDM', 'earDM',
#        '  TotleafDM', 'DrpLfDM', '  stemDM', ' rootDM', ' SoilRt', ' MxRtDep',
#        'AvailW', ' solubleC', 'Note     '],
#       dtype='object')

# %%
cols = ['date', 'jday', 'time', 'leaves', 'mature_lvs', 'dropped_lvs', 'LA', 'LA_dead', 'LAI', 'RH', 
        'leaf_WP', 'PFD', 'solrad', 'temp_soil', 'temp_air', 'temp_can', 'ET_dmd', 'ET_suply',
        'Pn', 'Pg', 'resp', 'av_gs', 'LAI_sunlit', 'LAI_shaded', 'PFD_sunlit', 'PFD_shaded', 
        'An_sunlit', 'An_shaded', 'Ag_sunlit', 'Ag_shaded', 'gs_sunlit', 'gs_shaded', 'VPD', 'nit', 'N_dmd', 'N_upt']

# %%
plt.plot(test.LAI)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-49e9ef899b23> in <module>()
# ----> 1 plt.plot(test.LAI)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'LAI'

# %%
plt.plot(test.earDM)

# %%
test = pd.read_csv('/home/disk/eos8/ach315/upscale/weadata/data/control/23023_1990.txt', sep='\s+', index_col=False)

# %%
test.head()
# Out:
#    jday          date  hour  solrad  temp  precip     rh  co2
# 0    91  '04/01/1990'     0     0.0  18.9     0.0  58.06  400
# 1    91  '04/01/1990'     1     0.0  17.8     0.0  62.29  400
# 2    91  '04/01/1990'     2     0.0  15.6     0.0  74.26  400
# 3    91  '04/01/1990'     3     0.0  15.0     0.0  77.22  400
# 4    91  '04/01/1990'     4     0.0  14.4     0.0  83.61  400

# %%
plt.plot(test.temp)

# %%
pwd
# Out:
# '/home/disk/eos8/ach315/upscale/notebooks'

# %%
test.head()
# Out:
#          date, Unnamed: 1  Unnamed: 2  Unnamed: 3  jday,  time,  Unnamed: 6  \
# 0  04/06/1964,     23473,         NaN         NaN    NaN    NaN         NaN
# 1  04/06/1964,     23473,         NaN         NaN    NaN    NaN         NaN
# 2  04/06/1964,     23473,         NaN         NaN    NaN    NaN         NaN
# 3  04/06/1964,     23473,         NaN         NaN    NaN    NaN         NaN
# 4  04/06/1964,     23473,         NaN         NaN    NaN    NaN         NaN
#
#   Unnamed: 7 Leaves,  MaturLvs,  ...  Unnamed: 112 totalDM,shootDM,earDM,  \
# 0        NaN      0,        NaN  ...           NaN             0.0000000,
# 1        NaN      1,        NaN  ...           NaN             0.0000000,
# 2        NaN      2,        NaN  ...           NaN             0.0000000,
# 3        NaN      3,        NaN  ...           NaN             0.0000000,
# 4        NaN      4,        NaN  ...           NaN             0.0000000,
#
# ...
