# %% [markdown]
# # Weather file - raw data process
# - Main task: reading in raw weather data from two sources and combine all output into .csv format <br/>
# - Data source:
#     1. NOAA Integrated Surface Data (ISH): https://www.ncdc.noaa.gov/isd/data-access
#     2. National Solar Radiation Database (NSRD): https://rredc.nrel.gov/solar/old_data/nsrdb/
#         - seems like can no longer reach this website (200626)
#         - new data access here: https://nsrdb.nrel.gov/data-sets/archives.html
# - Main output:
#     1. met data: df_temp_all, df_rh_all, df_precip_all
#     2. solarad data: df_solrad_all

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import glob
import time 
import datetime

# %% [markdown]
# ### Step 1. Hourly Meteorology Data - ISH
# - Main task:
#     - Read in and process raw met data
#     - Store output as dataframe and save as .csv
# - Main input:
#     - /data/**ISH/***
# - Main output:
#     - /weadata/**temp_all_6190.csv**
#     - /weadata/**precip_all_6190.csv**
#     - /weadata/**rh_all_6190.csv**

# %% [markdown]
# #### 1.1: function calculating RH with temp and dew point temp input
# Following the Clausius-Clapeyron relationship

# %%
# Creating Clausius-Clapeyron function

def CC(temp, temp_dew):
    """
    function that calculates relative humidity with temperature and dew point temperature
    temperautre input units: ˚C
    """
    # constant parameters
    Tref = 273.15  # reference temperature
    Es_Tref = 6.11 # saturation vapor pressure at reference temperature
    Lv = 2.5e+06   # latent heat of vaporation (J/kg)
    Rv = 461       # gas constant for moist air (J/kg)
    
    # transformed temperature inputs
    Tair = temp + Tref
    Tdew = temp_dew + Tref
    
    # Clausius-Clapeyron relation
    es = Es_Tref*np.exp((Lv/Rv)*(1/Tref - 1/Tair))
    e = Es_Tref*np.exp((Lv/Rv)*(1/Tref - 1/Tdew))
    rh = round(e/es,4)
    
    return(rh)

# %% [markdown]
# #### 1.2: read in individual met files and parse out data needed (1961-1990)

# %%
# %%time 
# run time ~30 mins

# timing related settings
years = np.arange(1961, 1991) # timeframe in which we have weather data
dateparse = lambda dates: [datetime.datetime.strptime(d, "%Y%m%d%H") for d in dates] # dateparsing method to be used in pd.read_fwf
season_start, season_end = '03-01-', '11-30-' # setting a pretty borad range for growing season

# setting up np.read_fwf arguments
colnames = ['time', 'temp', 'dew_temp', 'precip', 'precip_time', 'precip_depth', 'precip_condition', 'precip_quality', 'rh']
colspecs = [(15,25), (87,92), (93,98), (105,8193)]

# empty dataframes to store data from all site-years
df_temp_all = pd.DataFrame()
df_rh_all = pd.DataFrame()
df_precip_all = pd.DataFrame()

# reading in all weather data and storing as dataframe
for year in years:
    print(year) # output to track code progress
    times = pd.date_range(season_start + str(year), season_end + str(year) + ' 23:00:00', freq='1H')
    fnames = glob.glob('/home/disk/eos8/ach315/data/ISH/' + str(year) + '/*')
    
    # creating dataframes to store all site data for an individual year
    df_temp_sites = pd.DataFrame(index=times)
    df_rh_sites = pd.DataFrame(index=times)
    df_precip_sites = pd.DataFrame(index=times)
    
    for name in fnames:
        # WBAN site name 
        site_id = name.split('/')[-1].split('-')[-2]
        
        # read in individual files
        df = pd.read_fwf(name, names=colnames, colspecs=colspecs, header=None, index_col='time',
                         encoding='latin_1', dtype={'temp':int, 'precip':str}, 
                         parse_dates=True, date_parser=dateparse)
    
        # remove duplicated hours, keeping only the first measurement per hour
        df = df[df.index.duplicated(keep='first') == False]
        
        # add in missing time values (corrects for leap years) and keeps only growing season
        df = df.reindex(times, fill_value=np.nan)
        
        # finding precip data
        try:
            df.precip_time = df[df['precip'].str.find('ADDAA1')!=-1]['precip'].str.split('ADDAA1').str.get(1).str.slice(0,2).astype(float)
            df.precip_depth = df[df['precip'].str.find('ADDAA1')!=-1]['precip'].str.split('ADDAA1').str.get(1).str.slice(2, 6).astype(float)
            df.precip_condition = df[df['precip'].str.find('ADDAA1')!=-1]['precip'].str.split('ADDAA1').str.get(1).str.slice(6,7).astype(float)
            df.precip_quality = df[df['precip'].str.find('ADDAA1')!=-1]['precip'].str.split('ADDAA1').str.get(1).str.slice(7,8).astype(float)
        except: 
            print(year, name)
                
        # replacing missing data with NaN
        df.temp = df.temp.replace({9999: np.nan})
        
        # converting units 
        df.temp = df.temp/10
        df.dew_temp = df.dew_temp/10
        df.precip_depth = df.precip_depth/10
        
        # calculating RH through Clausius Clapeyron
        df.rh = CC(df.temp, df.dew_temp)*100

        # combining weather data into individual dataframes
        df_temp = pd.DataFrame({site_id: df.temp}, index= times)
        df_rh = pd.DataFrame({site_id: df.rh}, index=times)
        df_precip = pd.DataFrame({site_id: df.precip_depth}, index=times)
        
        df_temp_sites = pd.concat([df_temp_sites, df_temp], axis= 1, sort=True)
        df_rh_sites = pd.concat([df_rh_sites, df_rh], axis=1, sort=True)
        df_precip_sites = pd.concat([df_precip_sites, df_precip], axis=1, sort=True)

    # combining all site-years data together
    df_temp_all = pd.concat([df_temp_all, df_temp_sites], sort=True)
    df_rh_all = pd.concat([df_rh_all, df_rh_sites], sort=True)
    df_precip_all = pd.concat([df_precip_all, df_precip_sites], sort=True)
# Out:
# 1961
# 1962
# 1963
# 1964
# 1965
# 1966
# 1967
# 1968
# 1969
# 1970
# 1971
# 1972
# 1973
# 1974
# 1975
# 1976
# 1977
# 1978
# 1979
# 1980
# 1981
# 1982
# 1983
# 1984
# 1985
# 1986
# 1987
# 1988
# 1989
# 1990
# CPU times: user 26min 10s, sys: 37.7 s, total: 26min 48s
# Wall time: 29min 19s

# %%
#df_temp_all.to_csv('/home/disk/eos8/ach315/upscale/weadata/temp_6190.csv')
#df_precip_all.to_csv('/home/disk/eos8/ach315/upscale/weadata/precip_6190.csv')
#df_rh_all.to_csv('/home/disk/eos8/ach315/upscale/weadata/rh_6190.csv')

# %% [markdown]
# #### 1.4: read in individual met files and parse out data needed (1991-2010)

# %%
# reading in USAF site information - from solar radiation dataset
df_sites = pd.read_csv('/home/disk/eos8/ach315/upscale/weadata/stations_info_9110.csv')
print(df_sites.shape)
df_sites.head()

# select only class 1 stations (see NSRDB manual p.7-8 for more details)
df_class1 = df_sites[(df_sites['CLASS'] == 1)]
df_class1.shape
sites_class1 = list(df_class1.USAF) # station list with class 1 quality
# Out:
# (1454, 12)

# %% [markdown]
# # 200707 - rewriting portions of this code

# %%
year
# Out:
# 1991

# %%
site
# Out:
# 723530

# %%
name
# Out:
# '/home/disk/eos8/ach315/data/ISH/1991/723530-13967-1991'

# %%
df = pd.read_fwf(name, names=colnames, colspecs=colspecs, header=None, index_col='time',
                         encoding='latin_1', dtype={'temp':int, 'precip':str}, 
                         parse_dates=True, date_parser=dateparse)

df = df[df.index.duplicated(keep='first') == False]

        # add in missing time values (corrects for leap years) and keeps only growing season
df = df.reindex(times, fill_value=np.nan)

        # finding precip data
try:
    df.precip_time = df[df['precip'].str.find('ADDAA1')!=-1]['precip'].str.split('ADDAA1').str.get(1).str.slice(0,2).astype(float)
    df.precip_depth = df[df['precip'].str.find('ADDAA1')!=-1]['precip'].str.split('ADDAA1').str.get(1).str.slice(2, 6).astype(float)
    df.precip_condition = df[df['precip'].str.find('ADDAA1')!=-1]['precip'].str.split('ADDAA1').str.get(1).str.slice(6,7)
    df.precip_quality = df[df['precip'].str.find('ADDAA1')!=-1]['precip'].str.split('ADDAA1').str.get(1).str.slice(7,8)

    # filtering out precip data based on liquid precipitation quality code (data manual p.26)
    quality_flag = (df.precip_quality=='2') | (df.precip_quality=='3') | (df.precip_quality=='6') | (df.precip_quality=='7') | (df.precip_quality=='P')
    rows = df[quality_flag].index
    df.loc[rows].precip_depth = np.nan            
except: 
    print('bad precip!', name.split('/')[-1])   

df.temp = df.temp.replace({9999: np.nan})
df.precip_time = df.precip_time.replace({99: np.nan})
df.precip_depth = df.precip_depth.replace({9999: np.nan})

# converting units 
df.temp = df.temp/10
df.dew_temp = df.dew_temp/10
df.precip_depth = df.precip_depth/10

# calculating RH through Clausius Clapeyron
df.rh = CC(df.temp, df.dew_temp)*100

# combining weather data into individual dataframes
df_temp = pd.DataFrame({site: df.temp}, index= times)
df_rh = pd.DataFrame({site: df.rh}, index=times)
df_precip = pd.DataFrame({site: df.precip_depth}, index=times)

df_temp_sites = pd.concat([df_temp_sites, df_temp], axis= 1, sort=True)
df_rh_sites = pd.concat([df_rh_sites, df_rh], axis=1, sort=True)
df_precip_sites = pd.concat([df_precip_sites, df_precip], axis=1, sort=True)

# %%
# %%time

# timing related settings
years = np.arange(1991, 2011) # timeframe in which we have weather data
#years = np.arange(2000, 2011)
dateparse = lambda dates: [datetime.datetime.strptime(d, "%Y%m%d%H") for d in dates] # dateparsing method to be used in pd.read_fwf
season_start, season_end = '03-01-', '11-30-' # setting a pretty borad range for growing season

# setting up np.read_fwf arguments
colnames = ['time', 'temp', 'dew_temp', 'precip', 'precip_time', 'precip_depth', 'precip_condition', 'precip_quality', 'rh']
colspecs = [(15,25), (87,92), (93,98), (105,8193)]

# empty dataframes to store data from all site-years
df_temp_all = pd.DataFrame()
df_rh_all = pd.DataFrame()
df_precip_all = pd.DataFrame()

# reading in all weather data and storing as dataframe
for year in years:
    print(year) # output to track code progress
    times = pd.date_range(season_start + str(year), season_end + str(year) + ' 23:00:00', freq='1H')
    
    # creating dataframes to store all site data for an individual year
    df_temp_sites = pd.DataFrame(index=times)
    df_rh_sites = pd.DataFrame(index=times)
    df_precip_sites = pd.DataFrame(index=times)
    
    # setting up sites to iterate over
    sites_iter = iter(sites_class1)

    for site in sites_iter:
        # selecting for file associated with specified site
        file = glob.glob('/home/disk/eos8/ach315/data/ISH/' + str(year) + '/' + str(site) + '-*')
        
        if len(file) == 0: # when specified site does not exist for current year
            try:
                sites_iter.__next__() # move on to the next site if current site does not exist
                continue
            except:
                pass # pass the StopIteration error when reaches the end of iteration
        elif len(file) == 1:
            name = file[0]
        else: # when specified USAF site has more than one WBAN ID, resulting in more than one unique site
            name = glob.glob('/home/disk/eos8/ach315/data/ISH/' + str(year) + '/' + str(site) + '-99999-*')[0]
            # for cases when a USAF station ID is linked to two WBAN IDs, select the one in which WBAN is listed as 99999
            
        # reading in raw weather data as fixed-width data format
        df = pd.read_fwf(name, names=colnames, colspecs=colspecs, header=None, index_col='time',
                         encoding='latin_1', dtype={'temp':int, 'precip':str}, 
                         parse_dates=True, date_parser=dateparse)
        # remove duplicated hours, keeping only the first measurement per hour
        df = df[df.index.duplicated(keep='first') == False]

        # add in missing time values (corrects for leap years) and keeps only growing season
        df = df.reindex(times, fill_value=np.nan)

        # finding precip data
        try:
            df.precip_time = df[df['precip'].str.find('ADDAA1')!=-1]['precip'].str.split('ADDAA1').str.get(1).str.slice(0,2).astype(float)
            df.precip_depth = df[df['precip'].str.find('ADDAA1')!=-1]['precip'].str.split('ADDAA1').str.get(1).str.slice(2, 6).astype(float)
            df.precip_condition = df[df['precip'].str.find('ADDAA1')!=-1]['precip'].str.split('ADDAA1').str.get(1).str.slice(6,7)
            df.precip_quality = df[df['precip'].str.find('ADDAA1')!=-1]['precip'].str.split('ADDAA1').str.get(1).str.slice(7,8)
            
            # filtering out precip data based on liquid precipitation quality code (data manual p.26)
            quality_flag = (df.precip_quality=='2') | (df.precip_quality=='3') | (df.precip_quality=='6') | (df.precip_quality=='7') | (df.precip_quality=='P')
            rows = df[quality_flag].index
            df.loc[rows].precip_depth = np.nan            
        except: 
            print('bad precip!', name.split('/')[-1])            

        # replacing missing values with NANs                    
        df.temp = df.temp.replace({9999: np.nan})
        df.precip_time = df.precip_time.replace({99: np.nan})
        df.precip_depth = df.precip_depth.replace({9999: np.nan})

        # converting units 
        df.temp = df.temp/10
        df.dew_temp = df.dew_temp/10
        df.precip_depth = df.precip_depth/10

        # calculating RH through Clausius Clapeyron
        df.rh = CC(df.temp, df.dew_temp)*100

        # combining weather data into individual dataframes
        df_temp = pd.DataFrame({site: df.temp}, index= times)
        df_rh = pd.DataFrame({site: df.rh}, index=times)
        df_precip = pd.DataFrame({site: df.precip_depth}, index=times)

        df_temp_sites = pd.concat([df_temp_sites, df_temp], axis= 1, sort=True)
        df_rh_sites = pd.concat([df_rh_sites, df_rh], axis=1, sort=True)
        df_precip_sites = pd.concat([df_precip_sites, df_precip], axis=1, sort=True)       

    # combining all site-years data together
    df_temp_all = pd.concat([df_temp_all, df_temp_sites], sort=True)
    df_rh_all = pd.concat([df_rh_all, df_rh_sites], sort=True)
    df_precip_all = pd.concat([df_precip_all, df_precip_sites], sort=True)
# Out:
# 1991
# 1992
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in read_fwf(filepath_or_buffer, colspecs, widths, infer_nrows, **kwds)
#     780     kwds["infer_nrows"] = infer_nrows
#     781     kwds["engine"] = "python-fwf"
# --> 782     return _read(filepath_or_buffer, kwds)
#     783
#     784
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     452
#     453     try:
# --> 454         data = parser.read(nrows)
#     455     finally:
#     456         parser.close()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1131     def read(self, nrows=None):
#    1132         nrows = _validate_integer("nrows", nrows)
# -> 1133         ret = self._engine.read(nrows)
#    1134
#    1135         # May alter columns / col_dict
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, rows)
#    2429     def read(self, rows=None):
#    2430         try:
# -> 2431             content = self._get_lines(rows)
#    2432         except StopIteration:
#    2433             if self._first_chunk:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _get_lines(self, rows)
#    3179
#    3180                         while True:
# -> 3181                             new_row = self._next_iter_line(row_num=self.pos + rows + 1)
#    3182                             rows += 1
#    3183
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _next_iter_line(self, row_num)
#    2889
#    2890         try:
# -> 2891             return next(self.data)
#    2892         except csv.Error as e:
#    2893             if self.warn_bad_lines or self.error_bad_lines:
#
# KeyboardInterrupt:

# %%
# %%time

# timing related settings
years = np.arange(1991, 2011) # timeframe in which we have weather data
dateparse = lambda dates: [datetime.datetime.strptime(d, "%Y%m%d%H") for d in dates] # dateparsing method to be used in pd.read_fwf
season_start, season_end = '03-01-', '11-30-' # setting a pretty borad range for growing season

# setting up np.read_fwf arguments
colnames = ['time', 'temp', 'dew_temp', 'precip', 'precip_time', 'precip_depth', 'precip_condition', 'precip_quality', 'rh']
colspecs = [(15,25), (87,92), (93,98), (105,8193)]

# empty dataframes to store data from all site-years
df_temp_all = pd.DataFrame()
df_rh_all = pd.DataFrame()
df_precip_all = pd.DataFrame()

# reading in all weather data and storing as dataframe
for year in years:
    print(year) # output to track code progress
    times = pd.date_range(season_start + str(year), season_end + str(year) + ' 23:00:00', freq='1H')
    
    # creating dataframes to store all site data for an individual year
    df_temp_sites = pd.DataFrame(index=times)
    df_rh_sites = pd.DataFrame(index=times)
    df_precip_sites = pd.DataFrame(index=times)
    
    for site in sites_class1:
        # selecting for file associated with specified site
        file = glob.glob('/home/disk/eos8/ach315/data/ISH/' + str(year) + '/' + str(site) + '-*')
        if len(file) == 1:
            name = file[0]
            df = pd.read_fwf(name, names=colnames, colspecs=colspecs, header=None, index_col='time',
                             encoding='latin_1', dtype={'temp':int, 'precip':str}, 
                             parse_dates=True, date_parser=dateparse)
            # remove duplicated hours, keeping only the first measurement per hour
            df = df[df.index.duplicated(keep='first') == False]
        
            # add in missing time values (corrects for leap years) and keeps only growing season
            df = df.reindex(times, fill_value=np.nan)

            # finding precip data
            try:
                df.precip_time = df[df['precip'].str.find('ADDAA1')!=-1]['precip'].str.split('ADDAA1').str.get(1).str.slice(0,2).astype(float)
                df.precip_depth = df[df['precip'].str.find('ADDAA1')!=-1]['precip'].str.split('ADDAA1').str.get(1).str.slice(2, 6).astype(float)
                df.precip_condition = df[df['precip'].str.find('ADDAA1')!=-1]['precip'].str.split('ADDAA1').str.get(1).str.slice(6,7)
                df.precip_quality = df[df['precip'].str.find('ADDAA1')!=-1]['precip'].str.split('ADDAA1').str.get(1).str.slice(7,8)
                # filtering out precip data based on liquid precipitation quality code (data manual p.26)
                quality_flag = (df.precip_quality=='2') | (df.precip_quality=='3') | (df.precip_quality=='6') | (df.precip_quality=='7') | (df.precip_quality=='P')
                df.precip_depth[quality_flag] = np.nan
            except: 
                print('bad precip!', name.split('/')[-1])            
                  
            # replacing missing values with NANs                    
            df.temp = df.temp.replace({9999: np.nan})
            df.precip_time = df.precip_time.replace({99: np.nan})
            df.precip_depth = df.precip_depth.replace({9999: np.nan})

            # converting units 
            df.temp = df.temp/10
            df.dew_temp = df.dew_temp/10
            df.precip_depth = df.precip_depth/10

            # calculating RH through Clausius Clapeyron
            df.rh = CC(df.temp, df.dew_temp)*100

            # combining weather data into individual dataframes
            df_temp = pd.DataFrame({site: df.temp}, index= times)
            df_rh = pd.DataFrame({site: df.rh}, index=times)
            df_precip = pd.DataFrame({site: df.precip_depth}, index=times)

            df_temp_sites = pd.concat([df_temp_sites, df_temp], axis= 1, sort=True)
            df_rh_sites = pd.concat([df_rh_sites, df_rh], axis=1, sort=True)
            df_precip_sites = pd.concat([df_precip_sites, df_precip], axis=1, sort=True)        

        elif len(file) == 0:
            pass # year does not have specified site
        else:
            print('multiple files!', file)
            file = glob.glob('/home/disk/eos8/ach315/data/ISH/' + str(year) + '/' + str(site) + '99999-*')


    # combining all site-years data together
    df_temp_all = pd.concat([df_temp_all, df_temp_sites], sort=True)
    df_rh_all = pd.concat([df_rh_all, df_rh_sites], sort=True)
    df_precip_all = pd.concat([df_precip_all, df_precip_sites], sort=True)
# Out:
# 1991
# /home/disk/eos8/ach315/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 1992
# 1993
# 1994
# 1995
# 1996
# 1997
# 1998
# 1999
# 2000
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2000/700300-27503-2000', '/home/disk/eos8/ach315/data/ISH/2000/700300-99999-2000']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2000/722200-12832-2000', '/home/disk/eos8/ach315/data/ISH/2000/722200-99999-2000']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2000/722315-53917-2000', '/home/disk/eos8/ach315/data/ISH/2000/722315-99999-2000']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2000/722678-23052-2000', '/home/disk/eos8/ach315/data/ISH/2000/722678-99999-2000']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2000/722920-23191-2000', '/home/disk/eos8/ach315/data/ISH/2000/722920-99999-2000']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2000/723108-13776-2000', '/home/disk/eos8/ach315/data/ISH/2000/723108-99999-2000']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2000/723200-93801-2000', '/home/disk/eos8/ach315/data/ISH/2000/723200-99999-2000']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2000/724296-13841-2000', '/home/disk/eos8/ach315/data/ISH/2000/724296-99999-2000']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2000/724303-14813-2000', '/home/disk/eos8/ach315/data/ISH/2000/724303-99999-2000']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2000/724388-14829-2000', '/home/disk/eos8/ach315/data/ISH/2000/724388-99999-2000']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2000/724466-03929-2000', '/home/disk/eos8/ach315/data/ISH/2000/724466-99999-2000']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2000/724665-93010-2000', '/home/disk/eos8/ach315/data/ISH/2000/724665-99999-2000']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2000/725085-54756-2000', '/home/disk/eos8/ach315/data/ISH/2000/725085-99999-2000']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2000/725105-14770-2000', '/home/disk/eos8/ach315/data/ISH/2000/725105-99999-2000']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2000/725765-24061-2000', '/home/disk/eos8/ach315/data/ISH/2000/725765-99999-2000']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2000/725957-24215-2000', '/home/disk/eos8/ach315/data/ISH/2000/725957-99999-2000']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2000/726516-24024-2000', '/home/disk/eos8/ach315/data/ISH/2000/726516-99999-2000']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2000/726837-24162-2000', '/home/disk/eos8/ach315/data/ISH/2000/726837-99999-2000']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2000/727883-24220-2000', '/home/disk/eos8/ach315/data/ISH/2000/727883-99999-2000']
# 2001
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2001/700300-27503-2001', '/home/disk/eos8/ach315/data/ISH/2001/700300-99999-2001']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2001/722200-12832-2001', '/home/disk/eos8/ach315/data/ISH/2001/722200-99999-2001']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2001/722678-23052-2001', '/home/disk/eos8/ach315/data/ISH/2001/722678-99999-2001']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2001/723108-13776-2001', '/home/disk/eos8/ach315/data/ISH/2001/723108-99999-2001']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2001/723200-93801-2001', '/home/disk/eos8/ach315/data/ISH/2001/723200-99999-2001']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2001/724296-13841-2001', '/home/disk/eos8/ach315/data/ISH/2001/724296-99999-2001']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2001/724303-14813-2001', '/home/disk/eos8/ach315/data/ISH/2001/724303-99999-2001']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2001/724388-14829-2001', '/home/disk/eos8/ach315/data/ISH/2001/724388-99999-2001']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2001/724665-93010-2001', '/home/disk/eos8/ach315/data/ISH/2001/724665-99999-2001']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2001/725085-54756-2001', '/home/disk/eos8/ach315/data/ISH/2001/725085-99999-2001']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2001/725105-14770-2001', '/home/disk/eos8/ach315/data/ISH/2001/725105-99999-2001']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2001/725765-24061-2001', '/home/disk/eos8/ach315/data/ISH/2001/725765-99999-2001']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2001/725957-24215-2001', '/home/disk/eos8/ach315/data/ISH/2001/725957-99999-2001']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2001/726516-24024-2001', '/home/disk/eos8/ach315/data/ISH/2001/726516-99999-2001']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2001/726817-24154-2001', '/home/disk/eos8/ach315/data/ISH/2001/726817-99999-2001']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2001/726837-24162-2001', '/home/disk/eos8/ach315/data/ISH/2001/726837-99999-2001']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2001/727883-24220-2001', '/home/disk/eos8/ach315/data/ISH/2001/727883-99999-2001']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2001/747760-03818-2001', '/home/disk/eos8/ach315/data/ISH/2001/747760-99999-2001']
# 2002
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2002/700300-27503-2002', '/home/disk/eos8/ach315/data/ISH/2002/700300-99999-2002']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2002/700860-99999-2002', '/home/disk/eos8/ach315/data/ISH/2002/700860-27401-2002']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2002/722130-13861-2002', '/home/disk/eos8/ach315/data/ISH/2002/722130-99999-2002']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2002/722315-99999-2002', '/home/disk/eos8/ach315/data/ISH/2002/722315-53917-2002']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2002/722678-23052-2002', '/home/disk/eos8/ach315/data/ISH/2002/722678-99999-2002']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2002/722720-99999-2002', '/home/disk/eos8/ach315/data/ISH/2002/722720-93063-2002']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2002/722786-23104-2002', '/home/disk/eos8/ach315/data/ISH/2002/722786-99999-2002']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2002/722800-23195-2002', '/home/disk/eos8/ach315/data/ISH/2002/722800-99999-2002']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2002/722910-93116-2002', '/home/disk/eos8/ach315/data/ISH/2002/722910-99999-2002']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2002/722920-99999-2002', '/home/disk/eos8/ach315/data/ISH/2002/722920-23191-2002']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2002/722925-93117-2002', '/home/disk/eos8/ach315/data/ISH/2002/722925-99999-2002']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2002/723083-13763-2002', '/home/disk/eos8/ach315/data/ISH/2002/723083-99999-2002']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2002/723108-13776-2002', '/home/disk/eos8/ach315/data/ISH/2002/723108-99999-2002']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2002/723200-93801-2002', '/home/disk/eos8/ach315/data/ISH/2002/723200-99999-2002']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2002/724116-13868-2002', '/home/disk/eos8/ach315/data/ISH/2002/724116-99999-2002']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2002/724296-13841-2002', '/home/disk/eos8/ach315/data/ISH/2002/724296-99999-2002']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2002/724388-14829-2002', '/home/disk/eos8/ach315/data/ISH/2002/724388-99999-2002']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2002/724454-93996-2002', '/home/disk/eos8/ach315/data/ISH/2002/724454-99999-2002']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2002/724665-99999-2002', '/home/disk/eos8/ach315/data/ISH/2002/724665-93010-2002']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2002/724833-23206-2002', '/home/disk/eos8/ach315/data/ISH/2002/724833-99999-2002']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2002/724988-94704-2002', '/home/disk/eos8/ach315/data/ISH/2002/724988-99999-2002']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2002/725085-99999-2002', '/home/disk/eos8/ach315/data/ISH/2002/725085-54756-2002']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2002/725105-14770-2002', '/home/disk/eos8/ach315/data/ISH/2002/725105-99999-2002']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2002/725107-99999-2002', '/home/disk/eos8/ach315/data/ISH/2002/725107-04780-2002']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2002/725345-14834-2002', '/home/disk/eos8/ach315/data/ISH/2002/725345-99999-2002']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2002/725765-99999-2002', '/home/disk/eos8/ach315/data/ISH/2002/725765-24061-2002']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2002/726384-99999-2002', '/home/disk/eos8/ach315/data/ISH/2002/726384-14817-2002']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2002/726576-14928-2002', '/home/disk/eos8/ach315/data/ISH/2002/726576-99999-2002']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2002/726817-99999-2002', '/home/disk/eos8/ach315/data/ISH/2002/726817-24154-2002']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2002/726837-24162-2002', '/home/disk/eos8/ach315/data/ISH/2002/726837-99999-2002']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2002/727883-24220-2002', '/home/disk/eos8/ach315/data/ISH/2002/727883-99999-2002']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2002/744989-99999-2002', '/home/disk/eos8/ach315/data/ISH/2002/744989-14747-2002']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2002/747760-03818-2002', '/home/disk/eos8/ach315/data/ISH/2002/747760-99999-2002']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2002/910660-22701-2002', '/home/disk/eos8/ach315/data/ISH/2002/910660-99999-2002']
# 2003
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2003/700300-27503-2003', '/home/disk/eos8/ach315/data/ISH/2003/700300-99999-2003']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2003/700860-99999-2003', '/home/disk/eos8/ach315/data/ISH/2003/700860-27401-2003']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2003/722200-12832-2003', '/home/disk/eos8/ach315/data/ISH/2003/722200-99999-2003']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2003/722315-99999-2003', '/home/disk/eos8/ach315/data/ISH/2003/722315-53917-2003']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2003/722678-23052-2003', '/home/disk/eos8/ach315/data/ISH/2003/722678-99999-2003']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2003/722800-23195-2003', '/home/disk/eos8/ach315/data/ISH/2003/722800-99999-2003']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2003/722920-99999-2003', '/home/disk/eos8/ach315/data/ISH/2003/722920-23191-2003']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2003/723108-13776-2003', '/home/disk/eos8/ach315/data/ISH/2003/723108-99999-2003']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2003/723200-93801-2003', '/home/disk/eos8/ach315/data/ISH/2003/723200-99999-2003']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2003/724303-99999-2003', '/home/disk/eos8/ach315/data/ISH/2003/724303-14813-2003']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2003/724388-14829-2003', '/home/disk/eos8/ach315/data/ISH/2003/724388-99999-2003']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2003/724988-99999-2003', '/home/disk/eos8/ach315/data/ISH/2003/724988-94704-2003']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2003/725085-99999-2003', '/home/disk/eos8/ach315/data/ISH/2003/725085-54756-2003']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2003/725105-14770-2003', '/home/disk/eos8/ach315/data/ISH/2003/725105-99999-2003']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2003/725107-04780-2003', '/home/disk/eos8/ach315/data/ISH/2003/725107-99999-2003']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2003/725765-99999-2003', '/home/disk/eos8/ach315/data/ISH/2003/725765-24061-2003']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2003/725957-24215-2003', '/home/disk/eos8/ach315/data/ISH/2003/725957-99999-2003']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2003/726516-24024-2003', '/home/disk/eos8/ach315/data/ISH/2003/726516-99999-2003']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2003/726837-24162-2003', '/home/disk/eos8/ach315/data/ISH/2003/726837-99999-2003']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2003/727883-24220-2003', '/home/disk/eos8/ach315/data/ISH/2003/727883-99999-2003']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2003/744989-99999-2003', '/home/disk/eos8/ach315/data/ISH/2003/744989-14747-2003']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2003/747760-99999-2003', '/home/disk/eos8/ach315/data/ISH/2003/747760-03818-2003']
# 2004
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2004/702325-26443-2004', '/home/disk/eos8/ach315/data/ISH/2004/702325-99999-2004']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2004/722910-93116-2004', '/home/disk/eos8/ach315/data/ISH/2004/722910-99999-2004']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2004/725786-24151-2004', '/home/disk/eos8/ach315/data/ISH/2004/725786-99999-2004']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2004/726405-94869-2004', '/home/disk/eos8/ach315/data/ISH/2004/726405-99999-2004']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2004/726436-94930-2004', '/home/disk/eos8/ach315/data/ISH/2004/726436-99999-2004']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2004/727430-94850-2004', '/home/disk/eos8/ach315/data/ISH/2004/727430-99999-2004']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2004/742070-24201-2004', '/home/disk/eos8/ach315/data/ISH/2004/742070-99999-2004']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2004/747760-03818-2004', '/home/disk/eos8/ach315/data/ISH/2004/747760-99999-2004']
# 2005
# 2006
# 2007
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/700197-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/700197-26558-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/700300-27503-2007', '/home/disk/eos8/ach315/data/ISH/2007/700300-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/700634-27408-2007', '/home/disk/eos8/ach315/data/ISH/2007/700634-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/700860-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/700860-27401-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/701210-26624-2007', '/home/disk/eos8/ach315/data/ISH/2007/701210-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/701335-26648-2007', '/home/disk/eos8/ach315/data/ISH/2007/701335-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/701486-26642-2007', '/home/disk/eos8/ach315/data/ISH/2007/701486-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/701625-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/701625-26542-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/701745-26480-2007', '/home/disk/eos8/ach315/data/ISH/2007/701745-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/701975-26422-2007', '/home/disk/eos8/ach315/data/ISH/2007/701975-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/701995-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/701995-26628-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/702006-26502-2007', '/home/disk/eos8/ach315/data/ISH/2007/702006-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/702035-26704-2007', '/home/disk/eos8/ach315/data/ISH/2007/702035-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/702075-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/702075-26644-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/702223-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/702223-26602-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/702312-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/702312-26555-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/702325-26443-2007', '/home/disk/eos8/ach315/data/ISH/2007/702325-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/702595-26559-2007', '/home/disk/eos8/ach315/data/ISH/2007/702595-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/702615-26498-2007', '/home/disk/eos8/ach315/data/ISH/2007/702615-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/702648-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/702648-46406-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/702675-26484-2007', '/home/disk/eos8/ach315/data/ISH/2007/702675-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/702695-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/702695-96402-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/702715-46407-2007', '/home/disk/eos8/ach315/data/ISH/2007/702715-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/702746-26497-2007', '/home/disk/eos8/ach315/data/ISH/2007/702746-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/702755-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/702755-46404-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/702913-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/702913-46402-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/702915-26486-2007', '/home/disk/eos8/ach315/data/ISH/2007/702915-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/703334-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/703334-25519-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/703406-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/703406-26546-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/703407-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/703407-26553-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/703621-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/703621-25516-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/703644-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/703644-27515-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/703817-25357-2007', '/home/disk/eos8/ach315/data/ISH/2007/703817-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/703835-25628-2007', '/home/disk/eos8/ach315/data/ISH/2007/703835-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/703884-25376-2007', '/home/disk/eos8/ach315/data/ISH/2007/703884-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/703886-25348-2007', '/home/disk/eos8/ach315/data/ISH/2007/703886-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/722014-12818-2007', '/home/disk/eos8/ach315/data/ISH/2007/722014-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/722021-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/722021-92816-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/722022-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/722022-12803-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/722034-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/722034-12812-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/722049-92805-2007', '/home/disk/eos8/ach315/data/ISH/2007/722049-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/722067-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/722067-63823-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/722069-53853-2007', '/home/disk/eos8/ach315/data/ISH/2007/722069-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/722079-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/722079-53888-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/722123-12809-2007', '/home/disk/eos8/ach315/data/ISH/2007/722123-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/722134-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/722134-63822-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/722154-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/722154-53885-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/722156-53873-2007', '/home/disk/eos8/ach315/data/ISH/2007/722156-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/722176-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/722176-53884-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/722185-53838-2007', '/home/disk/eos8/ach315/data/ISH/2007/722185-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/722197-53819-2007', '/home/disk/eos8/ach315/data/ISH/2007/722197-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/722279-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/722279-53852-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/722285-03896-2007', '/home/disk/eos8/ach315/data/ISH/2007/722285-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/722312-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/722312-03908-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/722319-53943-2007', '/home/disk/eos8/ach315/data/ISH/2007/722319-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/722366-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/722366-53865-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/722427-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/722427-12975-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/722444-53902-2007', '/home/disk/eos8/ach315/data/ISH/2007/722444-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/722479-53907-2007', '/home/disk/eos8/ach315/data/ISH/2007/722479-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/722499-53948-2007', '/home/disk/eos8/ach315/data/ISH/2007/722499-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/722508-12957-2007', '/home/disk/eos8/ach315/data/ISH/2007/722508-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/722527-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/722527-12976-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/722537-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/722537-12961-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/722539-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/722539-12979-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/722547-53942-2007', '/home/disk/eos8/ach315/data/ISH/2007/722547-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/722552-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/722552-93929-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/722553-53928-2007', '/home/disk/eos8/ach315/data/ISH/2007/722553-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/722554-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/722554-12978-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/722587-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/722587-93955-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/722589-03991-2007', '/home/disk/eos8/ach315/data/ISH/2007/722589-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/722593-03985-2007', '/home/disk/eos8/ach315/data/ISH/2007/722593-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/722648-03031-2007', '/home/disk/eos8/ach315/data/ISH/2007/722648-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/722666-93943-2007', '/home/disk/eos8/ach315/data/ISH/2007/722666-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/722677-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/722677-03027-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/722683-93083-2007', '/home/disk/eos8/ach315/data/ISH/2007/722683-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/722689-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/722689-23077-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/722693-93097-2007', '/home/disk/eos8/ach315/data/ISH/2007/722693-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/722728-03196-2007', '/home/disk/eos8/ach315/data/ISH/2007/722728-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/722747-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/722747-93084-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/722748-03914-2007', '/home/disk/eos8/ach315/data/ISH/2007/722748-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/722783-03185-2007', '/home/disk/eos8/ach315/data/ISH/2007/722783-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/722787-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/722787-53126-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/722788-03186-2007', '/home/disk/eos8/ach315/data/ISH/2007/722788-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/722800-23195-2007', '/home/disk/eos8/ach315/data/ISH/2007/722800-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/722869-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/722869-03171-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/722895-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/722895-23243-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/722910-93116-2007', '/home/disk/eos8/ach315/data/ISH/2007/722910-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/722934-53121-2007', '/home/disk/eos8/ach315/data/ISH/2007/722934-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/722953-03183-2007', '/home/disk/eos8/ach315/data/ISH/2007/722953-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/722955-03174-2007', '/home/disk/eos8/ach315/data/ISH/2007/722955-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/722975-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/722975-53141-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/723065-13783-2007', '/home/disk/eos8/ach315/data/ISH/2007/723065-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/723079-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/723079-93796-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/723098-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/723098-93798-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/723104-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/723104-53867-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/723109-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/723109-93782-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/723114-03715-2007', '/home/disk/eos8/ach315/data/ISH/2007/723114-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/723116-03742-2007', '/home/disk/eos8/ach315/data/ISH/2007/723116-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/723117-53871-2007', '/home/disk/eos8/ach315/data/ISH/2007/723117-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/723118-53850-2007', '/home/disk/eos8/ach315/data/ISH/2007/723118-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/723124-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/723124-53874-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/723143-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/723143-03720-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/723144-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/723144-53890-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/723146-53892-2007', '/home/disk/eos8/ach315/data/ISH/2007/723146-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/723147-53870-2007', '/home/disk/eos8/ach315/data/ISH/2007/723147-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/723148-63859-2007', '/home/disk/eos8/ach315/data/ISH/2007/723148-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/723174-93783-2007', '/home/disk/eos8/ach315/data/ISH/2007/723174-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/723177-63807-2007', '/home/disk/eos8/ach315/data/ISH/2007/723177-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/723194-53872-2007', '/home/disk/eos8/ach315/data/ISH/2007/723194-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/723284-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/723284-93839-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/723300-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/723300-03975-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/723409-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/723409-53869-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/723429-53920-2007', '/home/disk/eos8/ach315/data/ISH/2007/723429-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/723434-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/723434-03973-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/723435-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/723435-53921-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/723439-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/723439-53918-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/723443-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/723443-53955-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/723447-03918-2007', '/home/disk/eos8/ach315/data/ISH/2007/723447-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/723449-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/723449-53954-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/723526-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/723526-03932-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/723528-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/723528-03981-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/723529-53929-2007', '/home/disk/eos8/ach315/data/ISH/2007/723529-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/723537-53913-2007', '/home/disk/eos8/ach315/data/ISH/2007/723537-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/723556-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/723556-93953-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/723564-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/723564-53908-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/723635-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/723635-03024-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/723647-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/723647-03034-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/723654-93091-2007', '/home/disk/eos8/ach315/data/ISH/2007/723654-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/723710-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/723710-03162-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/723754-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/723754-93027-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/723788-53135-2007', '/home/disk/eos8/ach315/data/ISH/2007/723788-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/723826-93194-2007', '/home/disk/eos8/ach315/data/ISH/2007/723826-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/723898-53119-2007', '/home/disk/eos8/ach315/data/ISH/2007/723898-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/724014-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/724014-93714-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/724017-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/724017-03707-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/724026-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/724026-03716-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/724033-03706-2007', '/home/disk/eos8/ach315/data/ISH/2007/724033-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/724036-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/724036-03710-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/724053-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/724053-03717-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/724057-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/724057-13701-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/724058-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/724058-53818-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/724074-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/724074-93780-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/724084-54760-2007', '/home/disk/eos8/ach315/data/ISH/2007/724084-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/724093-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/724093-13764-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/724107-53895-2007', '/home/disk/eos8/ach315/data/ISH/2007/724107-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/724117-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/724117-63802-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/724118-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/724118-93797-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/724276-53859-2007', '/home/disk/eos8/ach315/data/ISH/2007/724276-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/724284-63825-2007', '/home/disk/eos8/ach315/data/ISH/2007/724284-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/724285-13812-2007', '/home/disk/eos8/ach315/data/ISH/2007/724285-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/724295-63888-2007', '/home/disk/eos8/ach315/data/ISH/2007/724295-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/724347-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/724347-53904-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/724354-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/724354-63815-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/724365-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/724365-53896-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/724384-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/724384-53842-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/724385-04828-2007', '/home/disk/eos8/ach315/data/ISH/2007/724385-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/724504-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/724504-03974-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/724509-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/724509-53939-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/724627-03011-2007', '/home/disk/eos8/ach315/data/ISH/2007/724627-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/724636-03013-2007', '/home/disk/eos8/ach315/data/ISH/2007/724636-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/724674-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/724674-94050-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/724689-03026-2007', '/home/disk/eos8/ach315/data/ISH/2007/724689-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/724699-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/724699-03065-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/724700-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/724700-93141-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/724723-93025-2007', '/home/disk/eos8/ach315/data/ISH/2007/724723-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/724773-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/724773-93132-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/724776-93075-2007', '/home/disk/eos8/ach315/data/ISH/2007/724776-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/724828-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/724828-93241-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/724836-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/724836-23208-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/724973-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/724973-93203-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725015-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/725015-04789-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725027-54788-2007', '/home/disk/eos8/ach315/data/ISH/2007/725027-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725029-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/725029-64707-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725059-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/725059-14702-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725064-54769-2007', '/home/disk/eos8/ach315/data/ISH/2007/725064-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725075-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/725075-54768-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725079-14787-2007', '/home/disk/eos8/ach315/data/ISH/2007/725079-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725084-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/725084-54767-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725104-04843-2007', '/home/disk/eos8/ach315/data/ISH/2007/725104-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725113-54786-2007', '/home/disk/eos8/ach315/data/ISH/2007/725113-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725114-93778-2007', '/home/disk/eos8/ach315/data/ISH/2007/725114-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725119-54792-2007', '/home/disk/eos8/ach315/data/ISH/2007/725119-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725124-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/725124-64705-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725146-54773-2007', '/home/disk/eos8/ach315/data/ISH/2007/725146-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725175-64706-2007', '/home/disk/eos8/ach315/data/ISH/2007/725175-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725187-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/725187-94733-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725196-64775-2007', '/home/disk/eos8/ach315/data/ISH/2007/725196-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725207-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/725207-54735-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725208-04855-2007', '/home/disk/eos8/ach315/data/ISH/2007/725208-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725214-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/725214-04849-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725216-04842-2007', '/home/disk/eos8/ach315/data/ISH/2007/725216-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725217-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/725217-53855-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725224-04852-2007', '/home/disk/eos8/ach315/data/ISH/2007/725224-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725254-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/725254-04851-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725256-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/725256-04857-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725327-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/725327-04846-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725337-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/725337-04807-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725348-04831-2007', '/home/disk/eos8/ach315/data/ISH/2007/725348-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725349-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/725349-94982-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725354-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/725354-04806-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725378-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/725378-04887-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725384-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/725384-04888-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725394-04839-2007', '/home/disk/eos8/ach315/data/ISH/2007/725394-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725405-54816-2007', '/home/disk/eos8/ach315/data/ISH/2007/725405-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725406-54817-2007', '/home/disk/eos8/ach315/data/ISH/2007/725406-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725407-04854-2007', '/home/disk/eos8/ach315/data/ISH/2007/725407-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725408-04881-2007', '/home/disk/eos8/ach315/data/ISH/2007/725408-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725409-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/725409-04882-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725415-54821-2007', '/home/disk/eos8/ach315/data/ISH/2007/725415-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725416-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/725416-14864-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725417-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/725417-54822-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725434-54789-2007', '/home/disk/eos8/ach315/data/ISH/2007/725434-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725453-14930-2007', '/home/disk/eos8/ach315/data/ISH/2007/725453-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725456-04921-2007', '/home/disk/eos8/ach315/data/ISH/2007/725456-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725458-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/725458-04907-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725463-14966-2007', '/home/disk/eos8/ach315/data/ISH/2007/725463-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725464-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/725464-04977-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725466-04938-2007', '/home/disk/eos8/ach315/data/ISH/2007/725466-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725467-04973-2007', '/home/disk/eos8/ach315/data/ISH/2007/725467-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725468-04910-2007', '/home/disk/eos8/ach315/data/ISH/2007/725468-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725474-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/725474-04915-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725475-04953-2007', '/home/disk/eos8/ach315/data/ISH/2007/725475-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725476-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/725476-04916-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725477-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/725477-04917-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725478-04920-2007', '/home/disk/eos8/ach315/data/ISH/2007/725478-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725479-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/725479-04937-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725484-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/725484-04942-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725486-04906-2007', '/home/disk/eos8/ach315/data/ISH/2007/725486-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725488-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/725488-04955-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725489-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/725489-04959-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725494-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/725494-04966-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725497-04908-2007', '/home/disk/eos8/ach315/data/ISH/2007/725497-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725513-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/725513-04901-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725515-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/725515-94947-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725564-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/725564-04924-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725566-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/725566-04957-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725628-04935-2007', '/home/disk/eos8/ach315/data/ISH/2007/725628-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725665-94073-2007', '/home/disk/eos8/ach315/data/ISH/2007/725665-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725686-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/725686-94057-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725717-03016-2007', '/home/disk/eos8/ach315/data/ISH/2007/725717-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725763-94053-2007', '/home/disk/eos8/ach315/data/ISH/2007/725763-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/725869-94186-2007', '/home/disk/eos8/ach315/data/ISH/2007/725869-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/726056-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/726056-54791-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/726083-04836-2007', '/home/disk/eos8/ach315/data/ISH/2007/726083-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/726115-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/726115-54740-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/726130-14755-2007', '/home/disk/eos8/ach315/data/ISH/2007/726130-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/726163-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/726163-54770-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/726166-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/726166-54781-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/726225-64776-2007', '/home/disk/eos8/ach315/data/ISH/2007/726225-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/726284-94836-2007', '/home/disk/eos8/ach315/data/ISH/2007/726284-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/726364-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/726364-04883-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/726394-04874-2007', '/home/disk/eos8/ach315/data/ISH/2007/726394-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/726405-94869-2007', '/home/disk/eos8/ach315/data/ISH/2007/726405-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/726409-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/726409-04897-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/726414-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/726414-04873-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/726415-94854-2007', '/home/disk/eos8/ach315/data/ISH/2007/726415-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/726417-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/726417-54911-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/726418-54912-2007', '/home/disk/eos8/ach315/data/ISH/2007/726418-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/726424-94818-2007', '/home/disk/eos8/ach315/data/ISH/2007/726424-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/726425-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/726425-04841-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/726426-04895-2007', '/home/disk/eos8/ach315/data/ISH/2007/726426-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/726427-54908-2007', '/home/disk/eos8/ach315/data/ISH/2007/726427-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/726436-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/726436-94930-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/726437-94940-2007', '/home/disk/eos8/ach315/data/ISH/2007/726437-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/726438-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/726438-94994-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/726444-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/726444-04963-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/726449-04891-2007', '/home/disk/eos8/ach315/data/ISH/2007/726449-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/726464-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/726464-54834-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/726467-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/726467-54909-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/726514-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/726514-94032-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/726517-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/726517-94039-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/726518-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/726518-94990-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/726544-04958-2007', '/home/disk/eos8/ach315/data/ISH/2007/726544-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/726547-04931-2007', '/home/disk/eos8/ach315/data/ISH/2007/726547-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/726549-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/726549-54905-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/726554-54906-2007', '/home/disk/eos8/ach315/data/ISH/2007/726554-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/726561-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/726561-94997-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/726564-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/726564-04967-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/726567-04980-2007', '/home/disk/eos8/ach315/data/ISH/2007/726567-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/726569-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/726569-04933-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/726574-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/726574-94985-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/726577-94974-2007', '/home/disk/eos8/ach315/data/ISH/2007/726577-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/726578-04944-2007', '/home/disk/eos8/ach315/data/ISH/2007/726578-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/726596-04978-2007', '/home/disk/eos8/ach315/data/ISH/2007/726596-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/726603-04974-2007', '/home/disk/eos8/ach315/data/ISH/2007/726603-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/726626-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/726626-04864-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/726654-94054-2007', '/home/disk/eos8/ach315/data/ISH/2007/726654-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/726667-24048-2007', '/home/disk/eos8/ach315/data/ISH/2007/726667-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/726679-04969-2007', '/home/disk/eos8/ach315/data/ISH/2007/726679-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/726682-54914-2007', '/home/disk/eos8/ach315/data/ISH/2007/726682-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/726777-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/726777-94055-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/726813-94195-2007', '/home/disk/eos8/ach315/data/ISH/2007/726813-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/726816-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/726816-04110-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/726865-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/726865-24196-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/726883-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/726883-04113-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/726959-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/726959-94281-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/727135-94623-2007', '/home/disk/eos8/ach315/data/ISH/2007/727135-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/727430-94850-2007', '/home/disk/eos8/ach315/data/ISH/2007/727430-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/727434-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/727434-04870-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/727444-04979-2007', '/home/disk/eos8/ach315/data/ISH/2007/727444-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/727449-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/727449-04954-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/727452-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/727452-04912-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/727454-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/727454-04911-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/727456-04919-2007', '/home/disk/eos8/ach315/data/ISH/2007/727456-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/727466-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/727466-04918-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/727467-04926-2007', '/home/disk/eos8/ach315/data/ISH/2007/727467-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/727468-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/727468-04928-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/727486-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/727486-04983-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/727497-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/727497-04984-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/727503-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/727503-04909-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/727504-94999-2007', '/home/disk/eos8/ach315/data/ISH/2007/727504-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/727506-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/727506-04952-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/727508-54915-2007', '/home/disk/eos8/ach315/data/ISH/2007/727508-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/727514-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/727514-54910-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/727515-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/727515-04982-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/727533-04922-2007', '/home/disk/eos8/ach315/data/ISH/2007/727533-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/727556-04905-2007', '/home/disk/eos8/ach315/data/ISH/2007/727556-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/727566-04902-2007', '/home/disk/eos8/ach315/data/ISH/2007/727566-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/727584-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/727584-94038-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/727735-24139-2007', '/home/disk/eos8/ach315/data/ISH/2007/727735-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/727755-24112-2007', '/home/disk/eos8/ach315/data/ISH/2007/727755-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/727854-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/727854-94119-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/727885-94266-2007', '/home/disk/eos8/ach315/data/ISH/2007/727885-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/727890-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/727890-94197-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/727918-94298-2007', '/home/disk/eos8/ach315/data/ISH/2007/727918-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/727926-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/727926-24241-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/727945-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/727945-04205-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/727985-94276-2007', '/home/disk/eos8/ach315/data/ISH/2007/727985-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/744656-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/744656-53891-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/744657-53887-2007', '/home/disk/eos8/ach315/data/ISH/2007/744657-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/744658-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/744658-53889-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/744662-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/744662-63817-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/744663-53950-2007', '/home/disk/eos8/ach315/data/ISH/2007/744663-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/744665-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/744665-04838-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/744666-53944-2007', '/home/disk/eos8/ach315/data/ISH/2007/744666-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/744672-04862-2007', '/home/disk/eos8/ach315/data/ISH/2007/744672-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/745048-93210-2007', '/home/disk/eos8/ach315/data/ISH/2007/745048-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/745056-53120-2007', '/home/disk/eos8/ach315/data/ISH/2007/745056-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/745058-23277-2007', '/home/disk/eos8/ach315/data/ISH/2007/745058-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/745946-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/745946-93786-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/746925-03741-2007', '/home/disk/eos8/ach315/data/ISH/2007/746925-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/746929-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/746929-03702-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/746935-03709-2007', '/home/disk/eos8/ach315/data/ISH/2007/746935-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/746936-03712-2007', '/home/disk/eos8/ach315/data/ISH/2007/746936-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/746939-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/746939-93785-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/746940-03708-2007', '/home/disk/eos8/ach315/data/ISH/2007/746940-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/747040-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/747040-03102-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/747240-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/747240-03148-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/747806-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/747806-63809-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/747808-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/747808-63803-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/747809-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/747809-03832-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/747946-12886-2007', '/home/disk/eos8/ach315/data/ISH/2007/747946-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/785145-11653-2007', '/home/disk/eos8/ach315/data/ISH/2007/785145-99999-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/911975-99999-2007', '/home/disk/eos8/ach315/data/ISH/2007/911975-21510-2007']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2007/911977-21508-2007', '/home/disk/eos8/ach315/data/ISH/2007/911977-99999-2007']
# 2008
# 2009
# 2010
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2010/722045-12843-2010', '/home/disk/eos8/ach315/data/ISH/2010/722045-99999-2010']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2010/722146-12816-2010', '/home/disk/eos8/ach315/data/ISH/2010/722146-99999-2010']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2010/722347-13833-2010', '/home/disk/eos8/ach315/data/ISH/2010/722347-99999-2010']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2010/722720-93026-2010', '/home/disk/eos8/ach315/data/ISH/2010/722720-93063-2010']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2010/723183-13877-2010', '/home/disk/eos8/ach315/data/ISH/2010/723183-99999-2010']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2010/723246-53868-2010', '/home/disk/eos8/ach315/data/ISH/2010/723246-99999-2010']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2010/724089-13781-2010', '/home/disk/eos8/ach315/data/ISH/2010/724089-99999-2010']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2010/724236-03889-2010', '/home/disk/eos8/ach315/data/ISH/2010/724236-99999-2010']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2010/725033-94728-2010', '/home/disk/eos8/ach315/data/ISH/2010/725033-99999-2010']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2010/725035-04781-2010', '/home/disk/eos8/ach315/data/ISH/2010/725035-99999-2010']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2010/725095-94746-2010', '/home/disk/eos8/ach315/data/ISH/2010/725095-99999-2010']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2010/725115-14711-2010', '/home/disk/eos8/ach315/data/ISH/2010/725115-99999-2010']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2010/725246-14891-2010', '/home/disk/eos8/ach315/data/ISH/2010/725246-99999-2010']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2010/726796-24138-2010', '/home/disk/eos8/ach315/data/ISH/2010/726796-99999-2010']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2010/727854-94119-2010', '/home/disk/eos8/ach315/data/ISH/2010/727854-99999-2010']
# multiple files! ['/home/disk/eos8/ach315/data/ISH/2010/747930-12843-2010', '/home/disk/eos8/ach315/data/ISH/2010/747930-99999-2010']
# CPU times: user 1h 29min 16s, sys: 4min 6s, total: 1h 33min 22s
# Wall time: 1h 37min 21s

# %%
#df_temp_all.to_csv('/home/disk/eos8/ach315/data/ISH/temp_9110_class1.csv')
#df_precip_all.to_csv('/home/disk/eos8/ach315/data/ISH/precip_9110_class1.csv')
#df_rh_all.to_csv('/home/disk/eos8/ach315/data/ISH/rh_9110_class1.csv')

# %% [markdown]
# ### Step 2. Hourly Solar Radiation Data - NSRDB
# More data info: https://nsrdb.nrel.gov/about/u-s-data.html
# - Main task:
#     - Read in and process raw hourly solar radiation data
#     - Store output as dataframe and save as .csv
# - Main input:
#     - /data/**ISH_NSRD/***
# - Main output:
#     - **df_solrad_all**
#     - /weadata/solrad_all.csv

# %% [markdown]
# #### 2.1: Read in solar radiation data: 1961-1990

# %%
# %%time

years = np.arange(1961,1991) # test one year first
colnames = ['year', 'month', 'day', 'hour', 'solrad']
colspecs = [(1,3), (4,6), (7,9), (10,12), (23,27)]

df_solrad_all = pd.DataFrame()

for y in years:
    print(y)
    
    fnames = glob.glob('/home/disk/eos8/ach315/data/ISH_NSRD/' + str(y) + '/*')    
    df_solrad_sites = pd.DataFrame()
    
    for f in fnames:
        WBAN_id = str(f.split('/')[-1].split('_')[0])
        df = pd.read_fwf(f, skiprows=[0], header=None, 
                         names=colnames, colspecs=colspecs)
        time = df.apply(lambda row: datetime.datetime(y, row['month'], row['day'], row['hour']-1), axis=1)
        solrad = df['solrad'] # Global Horizontal Radiation (Wh/m2)
        df_solrad = pd.DataFrame(solrad)
        df_solrad.columns = [WBAN_id]
        df_solrad.index = time        
        df_solrad_sites = pd.concat([df_solrad_sites, df_solrad], axis=1, sort=True)
            
    df_solrad_all = pd.concat([df_solrad_all, df_solrad_sites], sort=True)

# convert 9999 values into NANs
df_solrad_all = df_solrad_all.replace({9999: np.nan})

# output all solar radiation data 1961-1990
#df_solrad_all.to_csv('/home/disk/eos8/ach315/upscale/weadata/solrad_all.csv')
# Out:
# 1961
# 1962
# 1963
# 1964
# 1965
# 1966
# 1967
# 1968
# 1969
# 1970
# 1971
# 1972
# 1973
# 1974
# 1975
# 1976
# 1977
# 1978
# 1979
# 1980
# 1981
# 1982
# 1983
# 1984
# 1985
# 1986
# 1987
# 1988
# 1989
# 1990
# CPU times: user 1h 28min 59s, sys: 1min 21s, total: 1h 30min 20s
# Wall time: 1h 32min 56s

# %% [markdown]
# #### 2.2 Read in solar radiation data: 1991-2010
# - Read in **METSTAT Glo (Wh/m2)**: METSTAT-modeled global horizontal
# - Total amount of direct and diffuse solar radiation (METSTAT-modeled) received on a horizontal surface during the 60-minute period ending at the timestamp <br/>
# - Refer to NSRDB data manla p.15 Table 3

# %%
# sample METSTAT Glo output
test = pd.read_csv('/home/disk/eos8/ach315/data/ISH_NSRD/2000/911650_2000_solar.csv')
plt.plot(test['METSTAT Glo (Wh/m^2)'])

# %% [markdown]
# Reading in USAF site information - from solar radiation dataset. <br/>
# Filtering out class 1 stations (see NSRDB manual p.7-8 for more details)
# - class 1: have complete period of record of 1991-2010
# - class 2: have complete period of record but with significant periods of interpolated, filler, or otherwise low-quality input data for solar models
# - class 3: have some gaps in the period of record but have at least 3 years of data

# %%
df_sites = pd.read_csv('/home/disk/eos8/ach315/data/ISH_NSRD/NSRDB_StationsMeta.csv')
print('all sites 1991-2010:', df_sites.shape[0])
df_sites.head()
df_class1 = df_sites[(df_sites['CLASS'] == 1)]
print('filtered class 1:', df_class1.shape[0])
# Out:
# all sites 1991-2010: 1454
# filtered class 1: 242

# %%
# %%time

sites_class1 = list(df_class1.USAF) # station list with class 1 quality
years = np.arange(1991,2011)
df_solrad_all = pd.DataFrame()

for year in years:    
    print(year)
    df_solrad_sites = pd.DataFrame()
    
    for site in sites_class1:
        file = glob.glob('/home/disk/eos8/ach315/data/ISH_NSRD/' + str(year) + '/' + str(site) + '_*.csv')
        if len(file) == 1:
            df = pd.read_csv(file[0])
            date = df['YYYY-MM-DD']
            time = df['HH:MM (LST)']
            datetimes = []
        else: 
            print('multiple files!', file)

        # formatting time info
        for i in np.arange(len(time)):
            year, month, day = date[i].split('-')
            hour = int(time[i].split(':')[0]) - 1
            date_time = datetime.datetime(int(year), int(month), int(day), int(hour))
            datetimes.append(date_time)

        # reading in solar rad file and selecting for measurement
        df_solrad = pd.DataFrame(df['METSTAT Glo (Wh/m^2)'])
        df_solrad.columns = [site]    
        df_solrad.index = datetimes
        
        # concatting all sites within year
        df_solrad_sites = pd.concat([df_solrad_sites, df_solrad], axis=1, sort=True)
    
    # concatting all years
    df_solrad_all = pd.concat([df_solrad_all, df_solrad_sites], sort=True)

# convert missing values into NANs
df_solrad_all = df_solrad_all.replace({-9900: np.nan})

# storing outputs
#df_solrad_all.to_csv('/home/disk/eos8/ach315/upscale/weadata/solrad_9110_class1.csv')
# Out:
# 1991
# 1992
# 1993
# 1994
# 1995
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# CPU times: user 46min 50s, sys: 13.4 s, total: 47min 3s
# Wall time: 49min 47s
