# %%
import numpy as np
import pandas as pd
import xarray as xr
import matplotlib.pyplot as plt
import seaborn as sns

# %%
temp = 15 + 8*np.random.randn(2,2,3)
precip = 10*np.random.randn(2,2,3)
lat = [[-99.83, -99.32], [-99.79, -99.23]]
lon = [[42.25, 42.21], [42.63, 42.59]]

# %%
data
# Out:
# array([[-0.00457397,  0.28479714,  0.18698703],
#        [ 1.59142139,  0.47644134, -0.71498101],
#        [-0.63364994,  0.17987983,  0.95752299],
#        [ 0.36663055,  1.03156939, -1.03245016]])

# %%
test = pd.DataFrame(data)

# %%
precip
# Out:
# array([[[  3.73467411,  -8.62740194, -10.46222052],
#         [ 15.54741179,  10.42209599, -13.00809187]],
#
#        [[-11.57133014,  -5.08415835,   5.6841826 ],
#         [ -3.10032512,  -2.84075132, -30.16343488]]])

# %%
ds = xr.Dataset({'temperature': (['x', 'y', 'time'], temp),
                 'precipitation': (['x', 'y', 'time'], precip)},
                coords = {'lon': (['x', 'y'], lon),
                          'lat': (['x', 'y'], lat),
                          'time': pd.date_range('2014-09-06', periods=3)})

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:        (time: 3, x: 2, y: 2)
# Coordinates:
#     lon            (x, y) float64 42.25 42.21 42.63 42.59
#     lat            (x, y) float64 -99.83 -99.32 -99.79 -99.23
#   * time           (time) datetime64[ns] 2014-09-06 2014-09-07 2014-09-08
# Dimensions without coordinates: x, y
# Data variables:
#     temperature    (x, y, time) float64 10.54 3.047 18.39 ... 4.03 14.01 12.0
#     precipitation  (x, y, time) float64 2.451 1.387 -5.016 ... 5.087 10.98

# %%
a = np.array([[1,2,3],[2,3,4]])
b = np.array([[3,4,5],[4,5,6]])

# %%
test = np.dstack((a,b))

# %%
test.shape
# Out:
# (2, 3, 2)
